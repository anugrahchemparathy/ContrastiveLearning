# %%
import numpy as np
import pandas as pd
import torch

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import sys
sys.path.append('../') # now can access entire repository, (important when running locally)

# %%
#from orbit_datasets import neworbits, versatileorbits, staticorbits
from ldcl.data.physics import get_dataset

# %%
#train_orbits_dataset = versatileorbits.OrbitsDataset()
train_orbits_dataset = get_dataset("orbit_config_default.json", "../saved_datasets")[0]
# Out:
# Current dE:  [1.33226763e-14]
# eccentricity:  [0.94646943]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [6], line 2
#       1 #train_orbits_dataset = versatileorbits.OrbitsDataset()
# ----> 2 train_orbits_dataset = get_dataset("orbit_config_default.json", "../saved_datasets")[0]
#
# File ~/Desktop/ml/lowdim-contrastive/ContrastiveLearning/ldcl/data/physics.py:424, in get_dataset(config, saved_dir)
#     422         raise ValueError("Config modality not specified")
#     423 elif config.dynamics == "orbits":
# --> 424     bundle = orbits_num_gen(config)
#     425     if config.modality == "image":
#     426         raise NotImplementedError
#
# File ~/Desktop/ml/lowdim-contrastive/ContrastiveLearning/ldcl/data/physics.py:301, in orbits_num_gen(config)
#     298     M = np.fmod(2 * np.pi * t / T, 2 * np.pi)  # mean anomaly
#     300     #try:
# --> 301     E = eccentric_anomaly_from_mean(e, M)  # eccentric anomaly
#     302     """except:
#     303         print("data generation failed.")
#     304         pass"""
#     305 phi = 2 * np.arctan2(np.sqrt(1 + e) * np.sin(E / 2), np.sqrt(1 - e) * np.cos(E / 2))  # true anomaly/angle
#
# File ~/Desktop/ml/lowdim-contrastive/ContrastiveLearning/ldcl/data/physics.py:266, in eccentric_anomaly_from_mean(e, M, tol)
#     264         print('Current dE: ', dE[dE > tol])
#     265         print('eccentricity: ', np.repeat(e, dE.shape[-1], axis=-1)[dE > tol])
# --> 266         raise RuntimeError(f'Did not converge after {MAX_ITERATIONS} iterations with tolerance {tol}.')
#     267 return E
#
# RuntimeError: Did not converge after 1000 iterations with tolerance 1e-14.

# %%
"""
Dims = (10240, 100, 4) = (numOrbits, numSamples, (posx,posy,momentumx,momentumy))
"""
train_orbits_dataset.data.shape
# Out:
# (10240, 10, 4)

# %%
fig, ax = plt.subplots()
for orbit_i in range(100):
    ax.scatter(train_orbits_dataset.data[orbit_i,:,0], train_orbits_dataset.data[orbit_i,:,1], alpha=.3) # position
#     ax.scatter(train_orbits_dataset.data[orbit_i,:,2], train_orbits_dataset.data[orbit_i,:,3], alpha=.3) # momentum

fig.set_size_inches(10, 8, forward=True)
ax.set(xlim=(-5, 5), ylim=(-5, 5))
# Out:
# [(-5.0, 5.0), (-5.0, 5.0)]
